# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import matplotlib.pyplot as plt
import numpy as np
import os
import math
from config import Base_url_one, Base_url_two
import time
import pandas as pd
import re

# %%
def get_page_num(driver, url):
    driver.get(url)
    try:
        page_info = driver.find_element_by_css_selector('.showing').text
        page_info = re.findall('[0-9]+',page_info)
        total_page_num = math.ceil(int(page_info[2]) / int(page_info[1]))
        print(total_page_num)
    except:
        total_page_num = 1
        pass    
    return total_page_num

# %%
def Find_items(driver_tab, url):
    information_tab = []
    driver_tab.get(url)
    time.sleep(5)
    
    try:
        information_tab.append(driver_tab.find_element_by_css_selector("dd[itemprop*='vehicleModelDate']").text)
    except:
        information_tab.append("N/A")

    try:
        information_tab.append(driver_tab.find_element_by_css_selector("dd[itemprop*='brand']").text)
    except:
        information_tab.append("N/A")

    try:
        information_tab.append(driver_tab.find_element_by_css_selector("dd[itemprop*='model']").text)
    except:
        information_tab.append("N/A")

    try:
        information_tab.append(driver_tab.find_element_by_css_selector("dd[itemprop*='bodyType']").text)
    except:
        information_tab.append("N/A")

    try:
        information_tab.append(driver_tab.find_element_by_css_selector("dd[itemprop*='driveWheelConfiguration']").text)
    except:
        information_tab.append("N/A")
        
    try:
        information_tab.append(driver_tab.find_element_by_css_selector("dd[itemprop*='mileageFromOdometer']").text)
    except:
        information_tab.append("N/A")
        
    try:
        information_tab.append(driver_tab.find_element_by_css_selector("span[itemprop*='price']").get_attribute("content"))
    except:
        information_tab.append("N/A")
        
    
    return information_tab

# %%
Main_List = []
Individal_List = []
url_links = []
url_links2 = []

chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--window-size=1920x1080")

chrome_driver = os.getcwd() +"\\chromedriver.exe"

driver = webdriver.Chrome(chrome_options=chrome_options, executable_path=chrome_driver)
driver_tab = webdriver.Chrome(chrome_options=chrome_options, executable_path=chrome_driver)

#driver = webdriver.Chrome("chromedriver.exe")
#driver_tab = webdriver.Chrome("chromedriver.exe")

for Num_page in range(2,get_page_num(driver, 'https://www.kijiji.ca/b-cars-trucks/ontario/subaru-impreza-new__used/c174l9004a54a1000054a49')+1):    
    time.sleep(5)
    url_links = (driver.find_elements_by_css_selector("div[class*='search-item']"))
    print(len(url_links))
    
    for listing in url_links:
        Individal_url = "https:/www.kijiji.ca"+ str(listing.get_attribute("data-vip-url"))
        Individal_List.append(Individal_url)
        Individal_List.append(str(listing.get_attribute("data-listing-id")))
        Individal_List.extend(Find_items(driver_tab, Individal_url))
        Main_List.append(Individal_List)
        Individal_List = []
        
    time.sleep(5)
    driver.get('https://www.kijiji.ca/b-cars-trucks/ontario/subaru-impreza-new__used/page-' + str(Num_page) + '/c174l9004a54a1000054a49')

print(Main_List)
driver_tab.close()
driver.quit()
# Out:
# c:\robodk\python37\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: use options instead of chrome_options
#   if sys.path[0] == '':
# c:\robodk\python37\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: use options instead of chrome_options
#   del sys.path[0]
# 11
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# [['https:/www.kijiji.ca/v-cars-trucks/north-bay/2017-subaru-impreza-touring/1488048060', '1488048060', '2017', 'Subaru', 'Impreza', 'Sedan', 'Other', '44,369', '19995.00'], ['https:/www.kijiji.ca/v-cars-trucks/guelph/2018-subaru-impreza-sport/1480823396', '1480823396', '2018', 'Subaru', 'Impreza', 'Sedan', 'All-wheel drive (AWD)', '28,651', '23898.00'], ['https:/www.kijiji.ca/v-cars-trucks/ottawa/2017-subaru-impreza-touring/1478513849', '1478513849', '2017', 'Subaru', 'Impreza', 'Hatchback', 'All-wheel drive (AWD)', '98,900', '17398.00'], ['https:/www.kijiji.ca/v-cars-trucks/london/2016-subaru-impreza-2-0i-awd-cam-1owner/1431221835', '1431221835', '2016', 'Subaru', 'Impreza', 'Hatchback', 'All-wheel drive (AWD)', '33,725', '20495.00'], ['https:/www.kijiji.ca/v-cars-trucks/cambridge/2010-subaru-impreza-wrx-custom-5speed-certified/1481098212', '1481098212', '2010', 'Subaru', 'Impreza', 'Sedan', 'All-wheel drive (AWD)', '175,000', '9995.00'], ['https:/www.kijiji.ca/v-cars-trucks/owen-sound/mint-2010-subaru-impreza/1495777073?undefined', '1495777073', '2010', 'Subaru', 'Impreza', 'Hatchback', 'All-wheel drive (AWD)', '59,000', '12000.00'], ['https:/www.kijiji.ca/v-cars-trucks/ottawa/2015-subaru-impreza-2-0i-w-touring-pkg/1484061185?undefined', '1484061185', '2015', 'Subaru', 'Impreza', 'Sedan', 'All-wheel drive (AWD)', '82,081', '14995.00'], ['https:/www.kijiji.ca/v-cars-trucks/ottawa/subaru-impreza-sport-awd-auto-hatchback-sunroof-heated-seats/1495759577?undefined', '1495759577', '2009', 'Subaru', 'Impreza', 'Hatchback', 'All-wheel drive (AWD)', '156,000', '5999.00'], ['https:/www.kijiji.ca/v-cars-trucks/city-of-toronto/2009-subaru-impreza-awd-finance-100-approved-3y-wrnty-available/1495750246?undefined', '1495750246', '2009', 'Subaru', 'Impreza', 'Sedan', 'All-wheel drive (AWD)', '155,310', '5650.00'], ['https:/www.kijiji.ca/v-cars-trucks/hamilton/2005-subaru-impreza-wagon/1495747445?undefined', '1495747445', '2005', 'Subaru', 'Impreza', 'Wagon', 'All-wheel drive (AWD)', '290,000', '2400.00'], ['https:/www.kijiji.ca/v-cars-trucks/kitchener-waterloo/2006-subaru-impreza-2-5x-awd-certified/1495739352?undefined', '1495739352', '2006', 'Subaru', 'Impreza', 'Hatchback', 'All-wheel drive (AWD)', '197,000', '4000.00'], ['https:/www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-subaru-impreza-limited-5-door-low-kms/1495730385?undefined', '1495730385', '2013', 'Subaru', 'Impreza', 'Hatchback', 'All-wheel drive (AWD)', '91,300', '12950.00'], ['https:/www.kijiji.ca/v-cars-trucks/ottawa/2016-subaru-impreza-2-0i-w-sport-pkg/1494327598?undefined', '1494327598', '2016', 'Subaru', 'Impreza', 'Sedan', 'All-wheel drive (AWD)', '68,418', '16998.00'], ['https:/www.kijiji.ca/v-cars-trucks/city-of-toronto/2016-subaru-impreza-premium-2-0i-awd-rearview-camera-43-638km/1495726706?undefined', '1495726706', '2016', 'Subaru', 'Impreza', 'Sedan', 'All-wheel drive (AWD)', '43,638', '11900.00'], ['https:/www.kijiji.ca/v-cars-trucks/mississauga-peel-region/silver-2015-subaru-impreza-low-km/1495719578?undefined', '1495719578', '2015', 'Subaru', 'Impreza', 'Hatchback', 'All-wheel drive (AWD)', '42,000', '19700.00'], ['https:/www.kijiji.ca/v-cars-trucks/oakville-halton-region/2016-subaru-impreza-wrx-wrx-awd-6spd-camera-bluetooth-certified/1419183189?undefined', '1419183189', '2016', 'Subaru', 'Impreza', 'Sedan', 'All-wheel drive (AWD)', '71,119', '25295.00'], ['https:/www.kijiji.ca/v-cars-trucks/oakville-halton-region/2017-subaru-impreza-wrx-wrx-awd-6-spd-camera-bluetooth-certified/1430794184?undefined', '1430794184', '2017', 'Subaru', 'Impreza', 'Sedan', 'All-wheel drive (AWD)', '73,991', '25995.00'], ['https:/www.kijiji.ca/v-cars-trucks/oakville-halton-region/2016-subaru-impreza-wrx-wrx-awd-6spd-camera-bluetooth-certified/1430078789?undefined', '1430078789', '2016', 'Subaru', 'Impreza', 'Sedan', 'All-wheel drive (AWD)', '77,959', '25795.00'], ['https:/www.kijiji.ca/v-cars-trucks/oakville-halton-region/2016-subaru-impreza-wrx-wrx-awd-6spd-manual-camera-bluetooth-c ...

# %%
df = pd.DataFrame(Main_List)
df.columns = ['Url', 'id','year', 'brand', 'model', 'bodytype' , 'drivingconfiguration', 'Odometer','Price']

# %%
df.to_csv('Listings.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-585c1955235d> in <module>
# ----> 1 df.to_csv('Listings.csv')
#
# NameError: name 'df' is not defined

# %%
df.round()
# Out:
#                                                    Url          id  year  \
# 0    https:/www.kijiji.ca/v-cars-trucks/north-bay/2...  1488048060  2017
# 1    https:/www.kijiji.ca/v-cars-trucks/guelph/2018...  1480823396  2018
# 2    https:/www.kijiji.ca/v-cars-trucks/ottawa/2017...  1478513849  2017
# 3    https:/www.kijiji.ca/v-cars-trucks/london/2016...  1431221835  2016
# 4    https:/www.kijiji.ca/v-cars-trucks/cambridge/2...  1481098212  2010
# ..                                                 ...         ...   ...
# 445  https:/www.kijiji.ca/v-cars-trucks/st-catharin...  1489166935  2002
# 446  https:/www.kijiji.ca/v-cars-trucks/mississauga...  1489085179  2013
# 447  https:/www.kijiji.ca/v-cars-trucks/oakville-ha...  1488974976  2012
# 448  https:/www.kijiji.ca/v-cars-trucks/markham-yor...  1489022666  2011
# 449  https:/www.kijiji.ca/v-cars-trucks/ottawa/2008...  1488961032  2008
#
#       brand    model   bodytype   drivingconfiguration Odometer     Price
# 0    Subaru  Impreza      Sedan                  Other   44,369  19995.00
# 1    Subaru  Impreza      Sedan  All-wheel drive (AWD)   28,651  23898.00
# 2    Subaru  Impreza  Hatchback  All-wheel drive (AWD)   98,900  17398.00
# 3    Subaru  Impreza  Hatchback  All-wheel drive (AWD)   33,725  20495.00
# 4    Subaru  Impreza      Sedan  All-wheel drive (AWD)  175,000   9995.00
# ..      ...      ...        ...                    ...      ...       ...
# 445  Subaru  Impreza      Wagon                    N/A  210,000   3000.00
# 446  Subaru  Impreza      Sedan  All-wheel drive (AWD)  170,000   7500.00
# 447  Subaru  Impreza      Sedan  All-wheel drive (AWD)  159,366  12500.00
# 448  Subaru  Impreza  Hatchback  All-wheel drive (AWD)  105,000  10000.00
# 449  Subaru  Impreza      Sedan  All-wheel drive (AWD)  146,720   4500.00
#
# [450 rows x 9 columns]

# %%
grouped = df.loc[(df["year"] == "2008") & (df["bodytype"] == "Hatchback")]

# %%
fig1, ax1 = plt.subplots()
data = list(map(float, grouped["Price"].tolist())) 
ax1.set_title("2008 Subaru Hatchback Prices")
ax1.boxplot(data)
plt.show()

# %%
x = list(map(int,pd.to_numeric(grouped["Price"].tolist())))
y = grouped["Odometer"].tolist()

for index, value  in enumerate(y):
    y[index] = int(value.replace(',', '')) 
    
m, b = np.polyfit(x, y, 1)

plt.scatter(x, y, marker='o');
plt.plot(x, np.asarray(m)*x + b)

# %%
print(m*25000 + b)
# Out:
# 24185.654498802236

# %%
print(grouped["Price"].quantile(.75))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-167-822eb126ff2d> in <module>
# ----> 1 print(x.quantile(.75))
#
# AttributeError: 'list' object has no attribute 'quantile'
